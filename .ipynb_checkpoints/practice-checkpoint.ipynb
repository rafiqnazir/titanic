# %%
import seaborn as sns
from scipy.stats import zscore
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('train.csv',index_col='PassengerId')
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.heatmap(df.isnull(),cmap="viridis",yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:ylabel='PassengerId'>

# %%
# hue= categorical data
sns.countplot(x='Survived',data=df,hue='Sex')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived',data=df,hue='Pclass')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='Pclass',y='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
plt.figure(figsize=(20,10))
sns.distplot(df['Fare'])
# Out:
# C:\Users\rafiq\Anaconda3\envs\data_science\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
df["Fare"]=df['Fare'].fillna(df['Fare'].mean())

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
def impute_age(cols):
    age=cols[0]
    pclass=cols[1]
    if pd.isnull(age):
        if pclass==1:
            return 37
        elif pclass==2:
            return 30
        else:
            return 25
    else:
        return age

# %%
df['Age']=df[['Age','Pclass']].apply(impute_age,axis=1)
df['Sex'] = df['Sex'].map( {'female': 1, 'male': 0} ).astype(int)

# %%
sns.heatmap(df.isnull(),cmap="viridis",yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:ylabel='PassengerId'>

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0
# 3                                       Heikkinen, Miss. Laina    1  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0
# 5                                     Allen, Mr. William Henry    0  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.corr()
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481  0.543351 -0.050671 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.131900 -0.400908  0.083081  0.018443 -0.549500
# Sex       0.543351 -0.131900  1.000000 -0.080129  0.114631  0.245489  0.182333
# Age      -0.050671 -0.400908 -0.080129  1.000000 -0.243190 -0.174439  0.119780
# SibSp    -0.035322  0.083081  0.114631 -0.243190  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443  0.245489 -0.174439  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.182333  0.119780  0.159651  0.216225  1.000000

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(df.corr(),vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
pclass_one_hot = pd.get_dummies(df['Pclass'], prefix='Pclass')
df = df.drop('Pclass', axis=1)
df = df.join(pclass_one_hot)

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(df.corr(),vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
enbarked_one_hot = pd.get_dummies(df['Embarked'], prefix='Embarked')
df = df.drop('Embarked', axis=1)
df = df.join(enbarked_one_hot)

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(df.corr(),vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
df['Alone']=df.apply(lambda row: row.Parch + row.SibSp>=1,axis=1)

# %%
df['Fare']=data['Fare'].astype(int)
plt.figure(figsize=(15, 7))

sns.heatmap(df.corr(),vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %%
data=df[['Sex','Fare','Pclass_1','Pclass_3','Embarked_C','Embarked_S','Embarked_Q','Survived','Alone']]
data.head()
# Out:
#              Sex  Fare  Pclass_1  Pclass_3  Embarked_C  Embarked_S  \
# PassengerId
# 1              0     7         0         1           0           1
# 2              1    71         1         0           1           0
# 3              1     7         0         1           0           1
# 4              1    53         1         0           0           1
# 5              0     8         0         1           0           1
#
#              Embarked_Q  Survived  Alone
# PassengerId
# 1                     0         0   True
# 2                     0         1   True
# 3                     0         1  False
# 4                     0         1   True
# 5                     0         0  False

# %%
train_data=pd.read_csv('train.csv',index_col='PassengerId')
test_data=pd.read_csv('test.csv',index_col='PassengerId')
train_data=data_preprocessing(train_data)
test_data=data_preprocessing(test_data)
train_data.head()
# Out:
#              Survived  Sex      Fare  Title  Cabin_Known  Embarked_Q  \
# PassengerId
# 1                   0    0 -0.502445      0            0           0
# 2                   1    1  0.786845      0            1           0
# 3                   1    1 -0.488854      0            0           0
# 4                   1    1  0.420730      0            1           0
# 5                   0    0 -0.486337      0            0           0
#
#              Embarked_S  Pclass_2  Pclass_3
# PassengerId
# 1                     1         0         1
# 2                     0         0         0
# 3                     1         0         1
# 4                     1         0         0
# 5                     1         0         1

# %%
from sklearn.preprocessing import StandardScaler

X = train_data.drop(['Survived'], axis=1).values.astype(float)

scale = StandardScaler()
X = scale.fit_transform(X)

Y = train_data['Survived'].values

# %%
from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(train_data.drop('Survived',axis=1),train_data['Survived'],test_size=0.3)

X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.33)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier

# from sklearn.linear_model import LogisticRegression

    
    
for i in range(10):
    X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.3)
#     clf = RandomForestClassifier(n_estimators = 1000,max_features=7,max_depth=6)
    clf = svm.SVC(kernel='rbf')
#     clf=DecisionTreeClassifier()
    clf=clf.fit(X_train,y_train)
    pred = clf.predict(X_test)
    print(metrics.accuracy_score(y_test,pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-5b86fffbecef> in <module>
#      14     clf = svm.SVC(kernel='precomputed')
#      15 #     clf=DecisionTreeClassifier()
# ---> 16     clf=clf.fit(X_train,y_train)
#      17     pred = clf.predict(X_test)
#      18     print(metrics.accuracy_score(y_test,pred))
#
# ~\Anaconda3\envs\data_science\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     186
#     187         if self.kernel == "precomputed" and n_samples != X.shape[1]:
# --> 188             raise ValueError("Precomputed matrix must be a square matrix."
#     189                              " Input is a {}x{} matrix."
#     190                              .format(X.shape[0], X.shape[1]))
#
# ValueError: Precomputed matrix must be a square matrix. Input is a 623x8 matrix.

# %%
def data_preprocessing(df):
        
    df['Title'] = df['Name'].apply(lambda x: x.split(',')[1].strip().split(' ')[0])
    df['Title'] = [0 if x in ['Mr.', 'Miss.', 'Mrs.'] else 1 for x in df['Title']]
    
    df['Cabin_Known'] = [0 if str(x) == 'nan' else 1 for x in df['Cabin']]
    
    df=df.drop(['Name','Ticket','Cabin','Age','Parch','SibSp'],axis=1)

    
    df['Sex'] = df['Sex'].map( {'female': 1, 'male': 0} ).astype(int)
    
    
    df['Fare']=df['Fare'].fillna(value=df['Fare'].mean())
    df['Fare']=zscore(df['Fare'])
    df['Embarked'] = df['Embarked'].fillna(value=df['Embarked'].mode())
        
    
    enbarked_one_hot = pd.get_dummies(df['Embarked'], prefix='Embarked',drop_first=True)
    df = df.drop('Embarked', axis=1)
    df = df.join(enbarked_one_hot)
    
    pclass_one_hot = pd.get_dummies(df['Pclass'], prefix='Pclass',drop_first=True)
    df = df.drop('Pclass', axis=1)
    df = df.join(pclass_one_hot)
    
#     df=df.drop(['Embarked_Q','Pclass_2'],axis=1)

    return df

# %%
train_data=pd.read_csv('train.csv',index_col='PassengerId')
test_data=pd.read_csv('test.csv',index_col='PassengerId')
train_data=data_preprocessing(train_data)
test_data=data_preprocessing(test_data)
train_data.head()
# Out:
#              Survived  Sex      Fare  Title  Cabin_Known  Embarked_Q  \
# PassengerId
# 1                   0    0 -0.502445      0            0           0
# 2                   1    1  0.786845      0            1           0
# 3                   1    1 -0.488854      0            0           0
# 4                   1    1  0.420730      0            1           0
# 5                   0    0 -0.486337      0            0           0
#
#              Embarked_S  Pclass_2  Pclass_3
# PassengerId
# 1                     1         0         1
# 2                     0         0         0
# 3                     1         0         1
# 4                     1         0         0
# 5                     1         0         1

# %%
from sklearn.preprocessing import StandardScaler

X = train_data.drop(['Survived'], axis=1).values.astype(float)

scale = StandardScaler()
X = scale.fit_transform(X)

Y = train_data['Survived'].values

# %%
clf =svm.SVC(kernel='rbf')
# clf = RandomForestClassifier(n_estimators = 1000,max_features=7,max_depth=6)
clf=clf.fit(X,Y)

# %%
scaled_test_data=test_data.values.astype(float)
scaled_test_data = scale.transform(scaled_test_data)
pred = clf.predict(scaled_test_data)
submission = pd.DataFrame({
    'PassengerId': test_data.index,
    'Survived': pred,
})

submission.sort_values('PassengerId', inplace=True)    
submission.to_csv('submission.csv', index=False)

# %%
test_data.head()
# Out:
#              Sex      Fare  Title  Embarked_C  Embarked_S  Pclass_1  Pclass_3
# PassengerId
# 892            0 -0.498407      0           0           0         0         1
# 893            1 -0.513274      0           0           1         0         1
# 894            0 -0.465088      0           0           0         0         0
# 895            0 -0.483466      0           0           1         0         1
# 896            1 -0.418471      0           0           1         0         1

# %%
submission.head(10)
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1
# 5          897         0
# 6          898         1
# 7          899         0
# 8          900         1
# 9          901         0

# %%
scale.var_
# Out:
# array([0.22821808, 1.        , 0.15300026, 0.20036756, 0.18365473,
#        0.24739224])

# %%
data=pd.DataFrame([[1,2,3,4],[10,1,30,8],[100,0,80,6]],columns=["first","second","third","fourth"])

# %%
data.head()
# Out:
#    first  second  third  fourth
# 0      1       2      3       4
# 1     10       1     30       8
# 2    100       0     80       6

# %%
sns.heatmap(data.corr(),vmin=-1,vmax=1,annot=True)
# Out:
# <AxesSubplot:>

# %%
a=np.array([1,2,3])
a.mean()
# Out:
# 2.0

# %%
df.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...

# %%
names =df['Name']

# %%
df['Title'] = df['Name'].apply(lambda x: x.split(',')[1].strip().split(' ')[0])
df['Title'] = [0 if x in ['Mr.', 'Miss.', 'Mrs.'] else 1 for x in df['Title']]

# %%
df['Title'].value_counts()
# Out:
# 0    824
# 1     67
# Name: Title, dtype: int64

# %%
sns.heatmap(df.corr(),vmin=-1,vmax=1,annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
sns.distplot(df['Age'].dropna().astype(int))
# Out:
# C:\Users\rafiq\Anaconda3\envs\data_science\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
d=df["Age"].copy()
df['Age'].dropna().astype(int)
# Out:
# PassengerId
# 1      22
# 2      38
# 3      26
# 4      35
# 5      35
#        ..
# 886    39
# 887    27
# 888    19
# 890    26
# 891    32
# Name: Age, Length: 714, dtype: int32

# %%
df['Cabin_Known'] = [0 if str(x) == 'nan' else 1 for x in df['Cabin']]

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...

# %%
sns.countplot(x='Survived',hue='Cabin_Known',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>
